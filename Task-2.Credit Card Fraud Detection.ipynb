# %% [markdown]
# ## IMPORTING DEPENDENCIES

# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
import sklearn.metrics as metrics
from sklearn.metrics import jaccard_score
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## LOADING DATA

# %%
df_train = pd.read_csv(r"C:\Users\anura\OneDrive\Desktop\Encryptix\Credit Card Fraud\fraudTrain.csv")

# %%
df_train
# Out:
#          Unnamed: 0 trans_date_trans_time               cc_num  \
# 0                 0   2019-01-01 00:00:18     2703186189652095
# 1                 1   2019-01-01 00:00:44         630423337322
# 2                 2   2019-01-01 00:00:51       38859492057661
# 3                 3   2019-01-01 00:01:16     3534093764340240
# 4                 4   2019-01-01 00:03:06      375534208663984
# ...             ...                   ...                  ...
# 1296670     1296670   2020-06-21 12:12:08       30263540414123
# 1296671     1296671   2020-06-21 12:12:19     6011149206456997
# 1296672     1296672   2020-06-21 12:12:32     3514865930894695
# 1296673     1296673   2020-06-21 12:13:36     2720012583106919
# 1296674     1296674   2020-06-21 12:13:37  4292902571056973207
#
#                                     merchant       category     amt  \
# 0                 fraud_Rippin, Kub and Mann       misc_net    4.97
# 1            fraud_Heller, Gutmann and Zieme    grocery_pos  107.23
# ...

# %%
df_test=pd.read_csv(r"C:\Users\anura\OneDrive\Desktop\Encryptix\Credit Card Fraud\fraudTest.csv")

# %%
df_test
# Out:
#         Unnamed: 0 trans_date_trans_time            cc_num  \
# 0                0   2020-06-21 12:14:25  2291163933867244
# 1                1   2020-06-21 12:14:33  3573030041201292
# 2                2   2020-06-21 12:14:53  3598215285024754
# 3                3   2020-06-21 12:15:15  3591919803438423
# 4                4   2020-06-21 12:15:17  3526826139003047
# ...            ...                   ...               ...
# 555714      555714   2020-12-31 23:59:07    30560609640617
# 555715      555715   2020-12-31 23:59:09  3556613125071656
# 555716      555716   2020-12-31 23:59:15  6011724471098086
# 555717      555717   2020-12-31 23:59:24     4079773899158
# 555718      555718   2020-12-31 23:59:34  4170689372027579
#
#                                     merchant        category     amt    first  \
# 0                      fraud_Kirlin and Sons   personal_care    2.86     Jeff
# 1                       fraud_Sporer-Keebler   personal_care   29.84   Joanne
# ...

# %% [markdown]
# ## DATA PRE PROCESSING

# %%
# TRAIN DATA
df_train.shape
# Out:
# (1296675, 23)

# %%
df_train.isnull().sum()
# Out:
# Unnamed: 0               0
# trans_date_trans_time    0
# cc_num                   0
# merchant                 0
# category                 0
# amt                      0
# first                    0
# last                     0
# gender                   0
# street                   0
# city                     0
# state                    0
# zip                      0
# lat                      0
# long                     0
# city_pop                 0
# job                      0
# dob                      0
# trans_num                0
# unix_time                0
# merch_lat                0
# merch_long               0
# is_fraud                 0
# dtype: int64

# %%
df_train.dtypes
# Out:
# Unnamed: 0                 int64
# trans_date_trans_time     object
# cc_num                     int64
# merchant                  object
# category                  object
# amt                      float64
# first                     object
# last                      object
# gender                    object
# street                    object
# city                      object
# state                     object
# zip                        int64
# lat                      float64
# long                     float64
# city_pop                   int64
# job                       object
# dob                       object
# trans_num                 object
# unix_time                  int64
# merch_lat                float64
# merch_long               float64
# is_fraud                   int64
# dtype: object

# %%
#Dropping columns with high cardianality,unique aobjects and indexing
df_train.drop(columns=["Unnamed: 0", "trans_num", "street"], inplace= True)

# %%
df_train.shape
# Out:
# (1296675, 20)

# %%
df_train
# Out:
#         trans_date_trans_time               cc_num  \
# 0         2019-01-01 00:00:18     2703186189652095
# 1         2019-01-01 00:00:44         630423337322
# 2         2019-01-01 00:00:51       38859492057661
# 3         2019-01-01 00:01:16     3534093764340240
# 4         2019-01-01 00:03:06      375534208663984
# ...                       ...                  ...
# 1296670   2020-06-21 12:12:08       30263540414123
# 1296671   2020-06-21 12:12:19     6011149206456997
# 1296672   2020-06-21 12:12:32     3514865930894695
# 1296673   2020-06-21 12:13:36     2720012583106919
# 1296674   2020-06-21 12:13:37  4292902571056973207
#
#                                     merchant       category     amt  \
# 0                 fraud_Rippin, Kub and Mann       misc_net    4.97
# 1            fraud_Heller, Gutmann and Zieme    grocery_pos  107.23
# 2                       fraud_Lind-Buckridge  entertainment  220.11
# 3         fraud_Kutch, Hermiston and Farrell  gas_transport   45.00
# ...

# %%
data = df_train.head(n = 20000)

# %%
data.is_fraud.value_counts()  #finding is_fraud values in that 20000 rows
# Out:
# is_fraud
# 0    19850
# 1      150
# Name: count, dtype: int64

# %%
#Converting categorical values into binary for easily applying M.L algos
df_processed = pd.get_dummies(data=data)

# %% [markdown]
# short example of pd.get_dummies()
# con = pd.Series(list('abcba'))
# print(pd.get_dummies(con))
# ![dummy1.png](attachment:37d34807-eb9b-4c1b-9f60-904c0ff2a1ab.png)

# %%
df_processed
# Out:
#                  cc_num     amt    zip      lat      long  city_pop  \
# 0      2703186189652095    4.97  28654  36.0788  -81.1781      3495
# 1          630423337322  107.23  99160  48.8878 -118.2105       149
# 2        38859492057661  220.11  83252  42.1808 -112.2620      4154
# 3      3534093764340240   45.00  59632  46.2306 -112.1138      1939
# 4       375534208663984   41.96  24433  38.4207  -79.4629        99
# ...                 ...     ...    ...      ...       ...       ...
# 19995  4104312520615374   98.86  92561  33.6401 -116.5567      1661
# 19996    30343344410970    2.04  16239  41.4622  -79.1306      4172
# 19997  3502088871723054   38.52  20895  39.0298  -77.0793     19054
# 19998  2706977570537524  110.12  45698  39.2830  -82.3977       341
# 19999   345389171551808   52.22  38922  33.9215  -89.6782      3451
#
#         unix_time  merch_lat  merch_long  is_fraud  ...  dob_2001-07-10  \
# 0      1325376018  36.011293  -82.048315         0  ...           False
# ...

# %%
df_processed.shape
# Out:
# (20000, 23553)

# %%
x_train = df_processed.drop(columns='is_fraud', axis=1)
y_train = df_processed['is_fraud']   #Target Variable

# %%
# FOR TEST DATA
df_test.drop(columns=["Unnamed: 0", "trans_num", "street"], inplace= True)
df_test
# Out:
#        trans_date_trans_time            cc_num  \
# 0        2020-06-21 12:14:25  2291163933867244
# 1        2020-06-21 12:14:33  3573030041201292
# 2        2020-06-21 12:14:53  3598215285024754
# 3        2020-06-21 12:15:15  3591919803438423
# 4        2020-06-21 12:15:17  3526826139003047
# ...                      ...               ...
# 555714   2020-12-31 23:59:07    30560609640617
# 555715   2020-12-31 23:59:09  3556613125071656
# 555716   2020-12-31 23:59:15  6011724471098086
# 555717   2020-12-31 23:59:24     4079773899158
# 555718   2020-12-31 23:59:34  4170689372027579
#
#                                     merchant        category     amt    first  \
# 0                      fraud_Kirlin and Sons   personal_care    2.86     Jeff
# 1                       fraud_Sporer-Keebler   personal_care   29.84   Joanne
# 2       fraud_Swaniawski, Nitzsche and Welch  health_fitness   41.28   Ashley
# 3                          fraud_Haley Group        misc_pos   60.05    Brian
# ...

# %%
df_test.shape
# Out:
# (555719, 20)

# %%
data_test = df_test.sample(frac=1, random_state=1).reset_index() #frac=1 used for randomly shuufle the rows and should return all rows
data_test = data_test.head(n = 5000)
data_test.is_fraud.value_counts()
# Out:
# is_fraud
# 0    4979
# 1      21
# Name: count, dtype: int64

# %%
df_processed_test = pd.get_dummies(data=data_test)

# %%
df_processed_test
# Out:
#        index               cc_num     amt    zip      lat      long  city_pop  \
# 0     207181     4229733778084049   41.17  42701  37.6848  -85.8784     48194
# 1     501018  4223708906367574214   51.89  45051  39.0965  -84.6431       177
# 2     312515       30175986190993    2.22  56592  47.5375  -95.9941       516
# 3     407433         675909898057   87.21  10504  41.1360  -73.7009      7987
# 4     386454       30092964733035   79.78  41056  38.6207  -83.8067     14228
# ...      ...                  ...     ...    ...      ...       ...       ...
# 4995  276550        4169388510116   30.92  14537  43.0330  -77.1575       207
# 4996   16702       36722699017270   77.00  85173  33.2887 -111.0985      2872
# 4997   72934      370877495212014  483.95  28659  36.2017  -81.1286     21134
# 4998  288038     4099707841315751  132.76  22968  38.2586  -78.4074      9815
# 4999   95565     2291163933867244  130.36  29209  33.9659  -80.9355    333497
#
# ...

# %%
x_test = df_processed.drop(columns='is_fraud', axis=1)
y_test = df_processed['is_fraud']

# %% [markdown]
# # MODELLING ON DIFFERENT CLASSIFIERS

# %% [markdown]
# ## 1.LOGISTIC REGRESSION

# %%
LR = LogisticRegression(solver='liblinear')
LR.fit(x_train, y_train)
# Out:
# LogisticRegression(solver='liblinear')

# %%
predictions1 = LR.predict(x_test)

# %%
predict_proba = LR.predict_proba(x_test)

# %%
predict_proba   #probabilities of class 0 and class 1
# Out:
# array([[0.5009927 , 0.4990073 ],
#        [0.50000023, 0.49999977],
#        [0.50001427, 0.49998573],
#        ...,
#        [0.50128608, 0.49871392],
#        [0.50099409, 0.49900591],
#        [0.50012684, 0.49987316]])

# %%
LR_Accuracy_Score = accuracy_score(y_test, predictions1)
print(LR_Accuracy_Score)
# Out:
# 0.9925

# %% [markdown]
# ## 2.DECESSION TREE

# %%
Tree = DecisionTreeClassifier()
Tree.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
predictions2 = Tree.predict(x_test)

# %%
Tree_Accuracy_Score = accuracy_score(y_test, predictions2)
Tree_JaccardIndex = jaccard_score(y_test, predictions2)
Tree_F1_Score = f1_score(y_test, predictions2)


print(Tree_Accuracy_Score)
print(Tree_JaccardIndex)
print(Tree_F1_Score)
# Out:
# 1.0
# 1.0
# 1.0

# %% [markdown]
# ## 3.RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestClassifier
RF=RandomForestClassifier()
RF.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
predictions3=RF.predict(x_test)

# %%
RF_accuracy=accuracy_score(y_test,predictions3)

# %%
print(RF_accuracy)
# Out:
# 1.0
